# %% [markdown]
# # サマースクール LLM　最終課題 レポート

# %%
# こちらのセルは最初に1度だけ実行してください
# こちらのセルは編集しないでください。
report = {
    "model_name": "",
    "model_hf_link": "",
    "model_github_link": "",
    "model_other_info_link": "",
    "kuhuu": "",
    "difficulty": "",
    "kanso": ""
}

# %% [markdown]
# ## 課題
#
#
# 上から回答していくと `submission_report.json`が作成されます。
# 提出期限までにomnicampusに提出してください。

# %% [markdown]
# Q1
# - 利用したモデル名
# - モデルのHuggingFaceのURL(HFに登録されている場合のみ)
# - モデルのGitHubのURL(GitHubに登録されている場合のみ)
# - その他モデルの情報(HF・GitHubどちらにもモデルの登録がない場合のみ)
#
# を教えてください

# %%
# 利用したモデル名
report["model_name"] = "matsuo-lab/weblab-10b-instruction-sft"

# モデルのHuggingFaceのURL(HFに登録されている場合のみ)
report["model_hf_link"] = "https://huggingface.co/matsuo-lab/weblab-10b-instruction-sft"

# モデルのGitHubのURL(GitHubに登録されている場合のみ)
report["model_github_link"] = "" # 登録がないので空白

# その他モデルの情報(HF・GitHubどちらにもモデルの登録がない場合のみ)
report["model_other_info_link"] = "" # HFに登録があるので空白

# %% [markdown]
# Q2 最終課題でのご自身の工夫点を教えてください。

# %%
# 以下はstarter codeの例です、自由に記述してください。
report["kuhuu"] = """
モデルの選定理由
日本語でフルスクラッチで学習されたモデルで最大サイズだったため、採用した

プロンプトの工夫
特に工夫なく、シンプルなプロンプトで行った。

学習の工夫
sample.jsonでLoRA finetuningを試したがあまり性能向上が期待されそうになかったので元のモデルのまま行った。

その他の工夫
文書要約タスク(type2)の入力文が長く、推論処理を早く終わらせるために最後の512tokenのみで要約タスクを行った。
"""

# %% [markdown]
# Q3 最終課題で苦労した部分を教えてください。

# %%
# 以下はstarter codeの例です、自由に記述してください。
report["difficulty"] = """
HuggingFace関連ライブラリのtransformersやPEFTライブラリの扱いに最初慣れなかったがドキュメントを読み込むなどしてとりあえず自分が試してみたかった処理を試すことができた。

モデルやプロンプトを網羅的に調べたり試したりして、なぜそのモデル・プロンプトを選んだかの自分なりの確信が得られたわけではないし、どうその決断をすべきか分からなかった。
"""

# %% [markdown]
# Q4 最終課題に取り組んだ感想を教えてください。

# %%
# 以下はstarter codeの例です、自由に記述してください。
report["kanso"] = """
ご自由に記述ください。
"""

# %%
list(report.keys())
# Out:
# ['model_name',
#  'model_hf_link',
#  'model_github_link',
#  'model_other_info_link',
#  'kuhuu',
#  'difficulty',
#  'kanso']

# %%
# omnicampusへ提出するjsonファイルが作成されます
import json
# 編集しないでください
assert list(report.keys()) == ['model_name', 'model_hf_link', 'model_github_link', 'model_other_info_link', 'kuhuu', 'difficulty', 'kanso'], '最初のセルで定義した辞書のkeyを編集しないでください'


# 編集しないでください
with open('/content/submission_report.json', 'w', encoding='utf-8') as json_file:
    json.dump(report, json_file, ensure_ascii=False, indent=4)
