# %% [markdown]
# # サマースクール LLM　最終課題 テストデータ作成
# 優秀者の決定の際に用いるデータを受講生の皆さんにも作成いただければと思います。
# 提出は任意で、提出の有無によって修了判定には影響しません。
# 皆さんから作成いただいたデータの中からランダムに抽出して評価に使用したいと思います。
#
# 全て作成いただかなくとも、1問だけ作成いただいてあとは空文字で提出いただいても構いません。

# %%
# こちらのセルは1度だけ実行してください
# こちらのセルは編集しないでください。
test_data = {
    "agreement": 0,
    "prompt": "",
    "sample_response": "",
    "multiple_choice_q": "",
    "multiple_choice": ["", "", "", "", ""],
    "multiple_choice_a": "",
    "summary_all_text": "",
    "summary_sample_a": ""
}

# %% [markdown]
# **Q1 作成するデータの公開範囲について同意できるものを教えてください。**
#
# 1. 最終課題のコンペのテストデータとして受講生に公開可
# 2. コンペのテストデータとして受講生に公開可、また研究用途として外部に公開可
# 3. 利用用途問わず公開可

# %%
# 1~3で回答をお願いします
test_data['agreement'] = # WRITE ME

assert test_data['agreement'] in [1, 2, 3]

# %% [markdown]
# **Q2 LLMへ与える指示文を作成してください。もし模範解答を作成できる場合は模範解答も作成してください**

# %%
test_data['prompt'] = """こちらにLLMへ与える指示文を作成してください。
普段ChatGPTやBingChatを使っているようなpromptやご自身がLLMを使用して解きたい特定のタスクなどを思い浮かべて作成いただければと思います。
Type3ではこちらに記入いただいたpromptが上位者のモデルに入力に使用されます。"""

test_data['sample_response'] = """もし模範解答を作成できる場合は模範解答も作成してください
もし模範解答を作成できる場合は模範解答も作成してください"""

# %% [markdown]
# **Q3 日本に関する知識を答える選択肢問題を作成してください**

# %%
# Type1のような、日本に関する知識に関する選択肢問題を作成してください
# 問題文
test_data['multiple_choice_q'] = ""

# 選択肢1
test_data['multiple_choice'][0] = ""
# 選択肢2
test_data['multiple_choice'][1] = ""
# 選択肢3
test_data['multiple_choice'][2] = ""
# 選択肢4
test_data['multiple_choice'][3] = ""
# 選択肢5
test_data['multiple_choice'][4] = ""

# 正解(作成した選択肢と同じ文字列を記入してください)
test_data['multiple_choice_a'] = ""

assert test_data['multiple_choice_a'] in test_data['multiple_choice']

# %% [markdown]
# **Q4　文章要約問題を作成してください**

# %%
# 文章要約の元となる文章を入力してください
test_data['summary_all_text'] = """
"""

# 模範解答を作成できる場合は解答を入力してください
test_data['summary_sample_a'] = ""

# %%
# omnicampusへ提出するjsonファイルが作成されます
import json

# 編集しないでください
with open('/content/submission_test_data.json', 'w', encoding='utf-8') as json_file:
    json.dump(test_data, json_file, ensure_ascii=False, indent=4)
