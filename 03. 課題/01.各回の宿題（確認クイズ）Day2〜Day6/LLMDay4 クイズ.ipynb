# %% [markdown]
# # サマースクール LLM　第4回 宿題

# %% [markdown]
# ## 課題
# 今回の課題は確認クイズです。
#
# 上から回答していくとcsv提出用csv `submission_pred.csv`が作成されます。
# 提出期限までにomnicampusに提出してください。
#
# **採点は締め切り後に一回だけ行われます。**
# （**即時採点ではありません。**）

# %%
# この部分は修正しないでください
import numpy as np
import pandas as pd

NUM_EXAMPLE_QUESTIONS = 1
example = np.zeros(NUM_EXAMPLE_QUESTIONS,int)

NUM_QUESTIONS = 5
myanswer = np.zeros(NUM_QUESTIONS,int)

# %% [markdown]
# ### 回答方法
# 各$\fbox{　(　)　}$に当てはまるものとして最も適切なものを1つずつ選んでください。
#
# **例題**
#
# 「深層学習/Deep Learning応用講座 – 生成モデル」の講義では$\fbox{　(0)　}$の技術に関して基礎的なアルゴリズムを幅広く利用可能で最先端の手法も理解し、実装することができることを目的とする。
#
# 1. 言語モデル
# 2. 生成モデル
# 3. 強化学習
# 4. ビジネスモデル
#
# 正しい回答を「生成モデル」とすると、以下のように0番目に2を数字で回答します．

# %% [markdown]
# ```python
# example[0] = 2
#
# ```

# %% [markdown]
# ### 確認クイズ
# **Q1 2020年にOpenAIから発表された[Scaling Lawに関しての論文](https://arxiv.org/abs/2001.08361)で示された性能とべき乗則が成り立つ3つの変数に含まれないものは以下のうちどれ？**
#
# 1. 層数(L)
# 2. 計算量(C)
# 3. パラメータ数(N)
# 4. データ量(D)
#
#
# 回答: $\fbox{　(0)　}$
#
# **Q2 Self-attentionの計算複雑度は系列長$n$を用いてどのように表される?**
#
# 1. O(n)
# 2. O($n\sqrt{n}$)
# 3. O($n^2$)
# 4. O($n^3$)
#
# 回答: $\fbox{　(1)　}$
#
# **Q3 メモリの読み書き時間に注目して高速化されたAttentionの改良手法は以下のうちどれ？**
#
# 1. ETC
# 2. Performer
# 3. Longformer
# 4. Flash-Attention
#
# 回答: $\fbox{　(2)　}$
#
# **Q4 深層学習モデルをレイヤ毎に分割し、分散学習を行う並列方法は以下のうちどれ？**
# 1. データ並列
# 2. オプティマイザ並列
# 3. パイプライン並列
# 4. テンソル並列
#
# 回答: $\fbox{　(3)　}$
#
# **Q5 自然言語処理タスクにおいてTransformerのスケーリングカーブを超えるとされる2023年に発表されたアーキテクチャは以下のうちどれ？**
#
# 1. RWKV
# 2. RetNet
# 3. CRNN
# 4. AlexNet
#
# 回答: $\fbox{　(4)　}$

# %%
myanswer[0] = # WRITE ME
myanswer[1] = # WRITE ME
myanswer[2] = # WRITE ME
myanswer[3] = # WRITE ME
myanswer[4] = # WRITE ME

# %%
# omnicampusへ提出するcsvファイルが作成されます。
if not np.any(myanswer==0):
    submission = pd.Series(myanswer, name='label')
    submission.to_csv('/content/submission_pred.csv', header=True, index_label='id')
else:
    print('Error: please answer all of the questions')
